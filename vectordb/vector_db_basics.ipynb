# %%
import chromadb
client = chromadb.Client()

# %%
collection=client.create_collection("news_articles")
collection.add(
    ids=["1", "2", "3","4"],
    documents=["The cat is on the table.", "The dog is in the garden.", "The bird is flying in the sky.","The fish is swimming in the pond."],
)
# Out:
# C:\Users\Varad Deshpande\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:27<00:00, 3.00MiB/s]
